# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta

# Get today's date
today = date.today()
d1 = today.strftime("%Y-%m-%d")
end_date = d1

# Set the start date to January 1, 2015
start_date = '2015-01-01'

# Download the data
data = yf.download('AAPL',
                      start=start_date,
                      end=end_date,
                      progress=False)

# Display the first few rows of the data
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.402174  212818400
# 2015-01-05  27.072500  27.162500  26.352501  26.562500  23.714722  257142000
# 2015-01-06  26.635000  26.857500  26.157499  26.565001  23.716951  263188400
# 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.049520  160423600
# 2015-01-08  27.307501  28.037500  27.174999  27.972500  24.973557  237458000

# %%
data["Date"] = data.index
data = data[["Date", "Open", "High",
             "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.402174  212818400
# 1 2015-01-05  27.072500  27.162500  26.352501  26.562500  23.714722  257142000
# 2 2015-01-06  26.635000  26.857500  26.157499  26.565001  23.716951  263188400
# 3 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.049520  160423600
# 4 2015-01-08  27.307501  28.037500  27.174999  27.972500  24.973557  237458000

# %%
data.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 2411 2024-08-02  219.149994  225.600006  217.710007  219.860001  219.860001
# 2412 2024-08-05  199.089996  213.500000  196.000000  209.270004  209.270004
# 2413 2024-08-06  205.300003  209.990005  201.070007  207.229996  207.229996
# 2414 2024-08-07  206.899994  213.639999  206.389999  209.820007  209.820007
# 2415 2024-08-08  213.110001  214.199997  208.830002  213.309998  213.309998
#
#          Volume
# 2411  105568600
# 2412  119548600
# 2413   69660500
# 2414   63516400
# 2415   44598400

# %%
data.to_csv('Apple_finance')
